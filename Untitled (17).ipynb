# %%
import numpy as np
import pandas as pd

# %%
dftrain = pd.read_csv('a.csv')
train = dftrain[dftrain['league'] == 'LEC']
train = train[train['position'] == 'team']
train = train.reset_index(drop = True)
# Out:
# C:\Users\rares\AppData\Local\Temp\ipykernel_17652\2377733350.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   dftrain = pd.read_csv('a.csv')

# %%
cols = ['Team', 'Oppo
# Out:
#                gameid datacompleteness  url league  year   split  playoffs  \
# 0    LOLTMNT06_164200         complete  NaN    LEC  2026  Versus         0
# 1    LOLTMNT06_164200         complete  NaN    LEC  2026  Versus         0
# 2    LOLTMNT06_163223         complete  NaN    LEC  2026  Versus         0
# 3    LOLTMNT06_163223         complete  NaN    LEC  2026  Versus         0
# 4    LOLTMNT06_164218         complete  NaN    LEC  2026  Versus         0
# ..                ...              ...  ...    ...   ...     ...       ...
# 487  LOLTMNT05_196637         complete  NaN    LEC  2026  Spring         1
# 488  LOLTMNT05_195687         complete  NaN    LEC  2026  Spring         1
# 489  LOLTMNT05_195687         complete  NaN    LEC  2026  Spring         1
# 490  LOLTMNT05_196638         complete  NaN    LEC  2026  Spring         1
# 491  LOLTMNT05_196638         complete  NaN    LEC  2026  Spring         1
#
# ...

# %%
train['result']
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 487    1
# 488    0
# 489    1
# 490    1
# 491    0
# Name: result, Length: 492, dtype: int64

# %%
train = train.drop(columns

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2952 entries, 1824 to 67511
# Columns: 165 entries, gameid to opp_deathsat25
# dtypes: float64(122), int64(20), object(23)
# memory usage: 3.7+ MB

# %%
dftrain.columns
# Out:
# Index(['gameid', 'datacompleteness', 'url', 'league', 'year', 'split',
#        'playoffs', 'date', 'game', 'patch',
#        ...
#        'opp_csat25', 'golddiffat25', 'xpdiffat25', 'csdiffat25', 'killsat25',
#        'assistsat25', 'deathsat25', 'opp_killsat25', 'opp_assistsat25',
#        'opp_deathsat25'],
#       dtype='object', length=165)

# %%
train[train['teamname'] == 'Fnatic']
# Out:
#                  gameid datacompleteness  url league  year   split  playoffs  \
# 1824   LOLTMNT06_164200         complete  NaN    LEC  2026  Versus         0
# 1825   LOLTMNT06_164200         complete  NaN    LEC  2026  Versus         0
# 1826   LOLTMNT06_164200         complete  NaN    LEC  2026  Versus         0
# 1827   LOLTMNT06_164200         complete  NaN    LEC  2026  Versus         0
# 1828   LOLTMNT06_164200         complete  NaN    LEC  2026  Versus         0
# ...                 ...              ...  ...    ...   ...     ...       ...
# 48666  LOLTMNT04_160242         complete  NaN    LEC  2026  Spring         0
# 48667  LOLTMNT04_160242         complete  NaN    LEC  2026  Spring         0
# 48668  LOLTMNT04_160242         complete  NaN    LEC  2026  Spring         0
# 48669  LOLTMNT04_160242         complete  NaN    LEC  2026  Spring         0
# 48671  LOLTMNT04_160242         complete  NaN    LEC  2026  Spring         0
#
# ...

# %%
import pandas as pd
keep_cols = [
    'gameid', 'date', 'patch', 'year', 'split', 'playoffs',
    'teamname', 'side',
    
    'result',
    
    'gamelength', 'ckpm', 'gspd', 'gpr',
    'golddiffat15', 'xpdiffat15', 'csdiffat15',
    'firstblood', 'firstdragon', 'firstbaron', 'firsttower',
    'dragons', 'barons', 'kills', 'deaths'
]

train = train[keep_cols]

# %%
train
# Out:
#                gameid                 date  patch  year   split  playoffs  \
# 0    LOLTMNT06_164200  2026-01-17 16:08:02  16.01  2026  Versus         0
# 1    LOLTMNT06_164200  2026-01-17 16:08:02  16.01  2026  Versus         0
# 2    LOLTMNT06_163223  2026-01-17 17:06:08  16.01  2026  Versus         0
# 3    LOLTMNT06_163223  2026-01-17 17:06:08  16.01  2026  Versus         0
# 4    LOLTMNT06_164218  2026-01-17 18:08:00  16.01  2026  Versus         0
# ..                ...                  ...    ...   ...     ...       ...
# 487  LOLTMNT05_196637  2026-06-07 17:09:58  16.10  2026  Spring         1
# 488  LOLTMNT05_195687  2026-06-07 18:07:19  16.10  2026  Spring         1
# 489  LOLTMNT05_195687  2026-06-07 18:07:19  16.10  2026  Spring         1
# 490  LOLTMNT05_196638  2026-06-07 18:59:23  16.10  2026  Spring         1
# 491  LOLTMNT05_196638  2026-06-07 18:59:23  16.10  2026  Spring         1
#
#           teamname  side  result     ban1  ... xpdiffat15 csdiffat15  \
# ...

# %%
print(train[train['position'] == 'team']['teamname'].value_counts())
# Out:
# teamname
# Karmine Corp         73
# G2 Esports           58
# Movistar KOI         57
# GiantX               50
# Team Vitality        48
# Natus Vincere        45
# Fnatic               38
# Team Heretics        36
# Shifters             33
# SK Gaming            32
# Los Ratones          11
# Karmine Corp Blue    11
# Name: count, dtype: int64
